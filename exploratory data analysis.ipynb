# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.iloc[:5,:]
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.size
# Out:
# 105684

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(include = ['object'])
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %%
df['show_id'].nunique()
# Out:
# 8807

# %%
df.set_index('show_id', inplace= True)

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.duplicated()
# Out:
# show_id
# s1       False
# s2       False
# s3       False
# s4       False
# s5       False
#          ...
# s8803    False
# s8804    False
# s8805    False
# s8806    False
# s8807    False
# Length: 8807, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
num_duplicated_row = df.duplicated().sum()

# %%
num_duplicated_row
# Out:
# 0

# %%
df.info
# Out:
# <bound method DataFrame.info of             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull()
# Out:
#           type  title  director   cast  country  date_added  release_year  \
# show_id
# s1       False  False     False   True    False       False         False
# s2       False  False      True  False    False       False         False
# s3       False  False     False  False     True       False         False
# s4       False  False      True   True     True       False         False
# s5       False  False      True  False    False       False         False
# ...        ...    ...       ...    ...      ...         ...           ...
# s8803    False  False     False  False    False       False         False
# s8804    False  False      True   True     True       False         False
# s8805    False  False     False  False    False       False         False
# s8806    False  False     False  False    False       False         False
# s8807    False  False     False  False    False       False         False
#
#          rating  duration  listed_in  description
# show_id
# ...

# %%
df.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 4307

# %%
df[['director','cast','country']] = df[['director','cast','country']].replace(np.nan, 'Unknown')

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# s4                                                 Unknown        Unknown
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.isnull().sum()
# Out:
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# directoe         0
# dtype: int64

# %%
df.dropna(subset=['date_added','rating','duration'], inplace = True)

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# s4                                                 Unknown        Unknown
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['date_added'].dtype
# Out:
# dtype('O')

# %%
df['date_added'] = df['date_added'].apply(pd.to_datetime)

# %%
df['date_added'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Loading year'] = df['date_added'].dt.year

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# s4                                                 Unknown        Unknown
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#         date_added  release_year rating   duration  \
# show_id
# s1      2021-09-25          2020  PG-13     90 min
# ...

# %%
df['Loading year']
# Out:
# show_id
# s1       2021
# s2       2021
# s3       2021
# s4       2021
# s5       2021
#          ...
# s8803    2019
# s8804    2019
# s8805    2019
# s8806    2020
# s8807    2019
# Name: Loading year, Length: 8790, dtype: int64

# %%
df.drop('date_added', axis=1, inplace=True)

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# s4                                                 Unknown        Unknown
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#          release_year rating   duration  \
# show_id
# s1               2020  PG-13     90 min
# s2               2021  TV-MA  2 Seasons
# ...

# %%
df.describe(include = ['int'])
# Out:
#        release_year  Loading year
# count   8790.000000   8790.000000
# mean    2014.183163   2018.873606
# std        8.825466      1.573568
# min     1925.000000   2008.000000
# 25%     2013.000000   2018.000000
# 50%     2017.000000   2019.000000
# 75%     2019.000000   2020.000000
# max     2021.000000   2021.000000

# %%
df['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df[['minutes','units']] = df['duration'].str.split(" ",expand = True)

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# s4                                                 Unknown        Unknown
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#          release_year rating   duration  \
# show_id
# s1               2020  PG-13     90 min
# s2               2021  TV-MA  2 Seasons
# ...

# %%
df['duration'].str.split(" ",expand = True)
# Out:
#            0        1
# show_id
# s1        90      min
# s2         2  Seasons
# s3         1   Season
# s4         1   Season
# s5         2  Seasons
# ...      ...      ...
# s8803    158      min
# s8804      2  Seasons
# s8805     88      min
# s8806     88      min
# s8807    111      min
#
# [8790 rows x 2 columns]

# %%
df_year = df[['release_year','Loading year']]

# %%
df_year
# Out:
#          release_year  Loading year
# show_id
# s1               2020          2021
# s2               2021          2021
# s3               2021          2021
# s4               2021          2021
# s5               2021          2021
# ...               ...           ...
# s8803            2007          2019
# s8804            2018          2019
# s8805            2009          2019
# s8806            2006          2020
# s8807            2015          2019
#
# [8790 rows x 2 columns]

# %%
df_year.head()
# Out:
#          release_year  Loading year
# show_id
# s1               2020          2021
# s2               2021          2021
# s3               2021          2021
# s4               2021          2021
# s5               2021          2021

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df_year.corr(),annot = True)
plt.show()

# %%
df['Loading year']
# Out:
# show_id
# s1       2021
# s2       2021
# s3       2021
# s4       2021
# s5       2021
#          ...
# s8803    2019
# s8804    2019
# s8805    2019
# s8806    2020
# s8807    2019
# Name: Loading year, Length: 8790, dtype: int64

# %%
df['Loading year'].value_counts().reset_index(name = 'count')
# Out:
#     index  count
# 0    2019   2016
# 1    2020   1879
# 2    2018   1648
# 3    2021   1498
# 4    2017   1185
# 5    2016    426
# 6    2015     82
# 7    2014     24
# 8    2011     13
# 9    2013     11
# 10   2012      3
# 11   2009      2
# 12   2008      2
# 13   2010      1

# %%
df['Loading year'].value_counts().reset_index(name='count')
# Out:
#     index  count
# 0    2019   2016
# 1    2020   1879
# 2    2018   1648
# 3    2021   1498
# 4    2017   1185
# 5    2016    426
# 6    2015     82
# 7    2014     24
# 8    2011     13
# 9    2013     11
# 10   2012      3
# 11   2009      2
# 12   2008      2
# 13   2010      1

# %%
plt.figure(figsize = (10,6))
sns.histplot(data=df,x='Loading year', bins=20, kde=True, color='red')
plt.title("Distribution of Loading Years")
plt.xlabel("Loading year")
plt.ylabel("Frequency")
plt.show()

# %%
df_year = df['release_year'].sort_values().head()

# %%
df_year
# Out:
# show_id
# s4251    1925
# s7791    1942
# s8206    1942
# s8764    1943
# s8740    1943
# Name: release_year, dtype: int64

# %%
df_year = df['release_year'].sort_values().head(150)
sns.set(style="whitegrid")
plt.figure(figsize = (10,8))
sns.countplot(x=df_year,palette='viridis')
plt.xlabel('Loading year')
plt.ylabel('count')
plt.title('Distribution of release year')
plt.xticks(rotation = 90)
plt.show()

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# s4                                                 Unknown        Unknown
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#          release_year rating   duration  \
# show_id
# s1               2020  PG-13     90 min
# s2               2021  TV-MA  2 Seasons
# ...

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
type_count = (df.groupby('type')['type'].count().reset_index(name='count'))

# %%
type_count
# Out:
#       type  count
# 0    Movie   6126
# 1  TV Show   2664

# %%
type_count
# Out:
#       type  count
# 0    Movie   6126
# 1  TV Show   2664

# %%
 sns.set(style='whitegrid')
plt.figure(figsize = (10,8))

sns.barplot(x = type_count['type'], y = type_count['count'], palette="Set2", ci=None)
plt.xlabel('type count')
plt.ylabel('count')
plt.title('"Distribution of Content Types')
plt.show()

# %%
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'release_year',
#        'rating', 'duration', 'listed_in', 'description', 'directoe',
#        'Loading year', 'minutes', 'units'],
#       dtype='object')

# %%
df [ (df['type'] == 'Movie') & (df['release_year'] == 2000)]
# Out:
#           type                                              title  \
# show_id
# s181     Movie                 The Nutty Professor II: The Klumps
# s351     Movie                                      Space Cowboys
# s360     Movie                       The Original Kings of Comedy
# s567     Movie                                   Charlie's Angels
# s594     Movie                                           Snow Day
# s780     Movie                                  Battlefield Earth
# s953     Movie                               The Whole Nine Yards
# s3473    Movie                        Rugrats in Paris: The Movie
# s4546    Movie             Monty Python: Before the Flying Circus
# s4724    Movie                                               Fiza
# s4957    Movie                        Phir Bhi Dil Hai Hindustani
# s5954    Movie                             Joseph: King of Dreams
# s6007    Movie                                            28 Days
# ...

# %%
df[(df['country']== 'India') & (df['type']== 'TV Show')]['title']
# Out:
# show_id
# s5                             Kota Factory
# s40                            Chhota Bheem
# s51                           Dharmakshetra
# s67           Raja Rasoi Aur Anya Kahaniyan
# s70          Stories by Rabindranath Tagore
#                         ...
# s8174                             Thackeray
# s8236                           The Calling
# s8322    The Golden Years with Javed Akhtar
# s8350                The House That Made Me
# s8776                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %%
df[(df['country']== 'India') & (df['type']== 'TV Show')].title
# Out:
# show_id
# s5                             Kota Factory
# s40                            Chhota Bheem
# s51                           Dharmakshetra
# s67           Raja Rasoi Aur Anya Kahaniyan
# s70          Stories by Rabindranath Tagore
#                         ...
# s8174                             Thackeray
# s8236                           The Calling
# s8322    The Golden Years with Javed Akhtar
# s8350                The House That Made Me
# s8776                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# s4                                                 Unknown        Unknown
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#          release_year rating   duration  \
# show_id
# s1               2020  PG-13     90 min
# s2               2021  TV-MA  2 Seasons
# ...

# %%
df['director'].value_counts().iloc[1:11]
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
print('Top 10 directors')

c = 0
for name in df['director'].value_counts().iloc[1:11].index:
    c += 1
    print(c,'\t:\t',name)
# Out:
# Top 10 directors
# 1 	:	 Rajiv Chilaka
# 2 	:	 Raúl Campos, Jan Suter
# 3 	:	 Suhas Kadav
# 4 	:	 Marcus Raboy
# 5 	:	 Jay Karas
# 6 	:	 Cathy Garcia-Molina
# 7 	:	 Martin Scorsese
# 8 	:	 Jay Chapman
# 9 	:	 Youssef Chahine
# 10 	:	 Steven Spielberg

# %%
data = df['director'].value_counts().iloc[1:11].to_dict()d

# %%
data
# Out:
# {'Rajiv Chilaka': 19,
#  'Raúl Campos, Jan Suter': 18,
#  'Suhas Kadav': 16,
#  'Marcus Raboy': 16,
#  'Jay Karas': 14,
#  'Cathy Garcia-Molina': 13,
#  'Martin Scorsese': 12,
#  'Jay Chapman': 12,
#  'Youssef Chahine': 12,
#  'Steven Spielberg': 11}

# %%
df2 = pd.DataFrame(list(data.items()), columns = ['director','count'])

# %%
df2
# Out:
#                  director  count
# 0           Rajiv Chilaka     19
# 1  Raúl Campos, Jan Suter     18
# 2             Suhas Kadav     16
# 3            Marcus Raboy     16
# 4               Jay Karas     14
# 5     Cathy Garcia-Molina     13
# 6         Martin Scorsese     12
# 7             Jay Chapman     12
# 8         Youssef Chahine     12
# 9        Steven Spielberg     11

# %%
explode = (0.09,0,0,0,0,0,0,0,0,0)

plt.figure(figsize = (10,8))
plt.pie(df2['count'],labels = df2['director'], autopct='%1.1f%%',startangle = 90, colors=sns.color_palette('viridis', n_colors=10), explode=explode)

plt.title('Top 10 Directors')
plt.show()

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# s4                                                 Unknown        Unknown
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#          release_year rating   duration  \
# show_id
# s1               2020  PG-13     90 min
# s2               2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ### all movies directed by jay karas

# %%
df[(df['director']== 'Jay Karas') & (df['type']== 'Movie')].title
# Out:
# show_id
# s2696                                       The Main Event
# s3734                  Adam Devine: Best Time of Our Lives
# s4804               Bill Burr: You People Are All the Same
# s4864                            Ali Wong: Hard Knock Wife
# s5087                              Tom Segura: Disgraceful
# s5231                         Christina P: Mother Inferior
# s5623                         Bill Burr: Walk Your Way Out
# s5809    Jeff Foxworthy and Larry the Cable Guy: We’ve ...
# s5818                           Jim Gaffigan: Mr. Universe
# s5848                                 Ali Wong: Baby Cobra
# s5876                           Tom Segura: Mostly Stories
# s5895                           Anjelah Johnson: Not Fancy
# s5900                   Demetri Martin: Live (At the Time)
# s5922               Bill Burr: I'm Sorry You Feel That Way
# Name: title, dtype: object

# %%
df[(df['director']== 'Jay Karas') & (df['type']== 'Movie')]
# Out:
#           type                                              title   director  \
# show_id
# s2696    Movie                                     The Main Event  Jay Karas
# s3734    Movie                Adam Devine: Best Time of Our Lives  Jay Karas
# s4804    Movie             Bill Burr: You People Are All the Same  Jay Karas
# s4864    Movie                          Ali Wong: Hard Knock Wife  Jay Karas
# s5087    Movie                            Tom Segura: Disgraceful  Jay Karas
# s5231    Movie                       Christina P: Mother Inferior  Jay Karas
# s5623    Movie                       Bill Burr: Walk Your Way Out  Jay Karas
# s5809    Movie  Jeff Foxworthy and Larry the Cable Guy: We’ve ...  Jay Karas
# s5818    Movie                         Jim Gaffigan: Mr. Universe  Jay Karas
# s5848    Movie                               Ali Wong: Baby Cobra  Jay Karas
# s5876    Movie                         Tom Segura: Mostly Stories  Jay Karas
# ...

# %%
df[(df['country']=='India') & (df['type']== 'Movie')]
# Out:
#           type                  title                 director  \
# show_id
# s25      Movie                  Jeans               S. Shankar
# s106     Movie       Angamaly Diaries     Lijo Jose Pellissery
# s115     Movie                 Anjaam             Rahul Rawail
# s117     Movie                 Dhanak          Nagesh Kukunoor
# s119     Movie                Gurgaon            Shanker Raman
# ...        ...                    ...                      ...
# s8773    Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# s8774    Movie    Yanda Kartavya Aahe             Kedar Shinde
# s8799    Movie               Zed Plus  Chandra Prakash Dwivedi
# s8800    Movie                  Zenda           Avadhoot Gupte
# s8807    Movie                 Zubaan              Mozez Singh
#
#                                                       cast country  \
# show_id
# s25      Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %% [markdown]
# ### In how many Movies and TV Shows, duration was 100 minutes

# %%
movie = df[(df['type'] == 'Movie') & (df['duration']== '100 min')]

# %%
movie
# Out:
#           type                                              title  \
# show_id
# s55      Movie  InuYasha the Movie: Affections Touching Across...
# s141     Movie                El patrón, radiografía de un crimen
# s301     Movie                                               Vivo
# s456     Movie               Emicida: AmarElo - Live in São Paulo
# s462     Movie                                  The Unknown Saint
# ...        ...                                                ...
# s8563    Movie                                The Women's Balcony
# s8623    Movie                             Tremors 2: Aftershocks
# s8628    Movie                                Trespass Against Us
# s8746    Movie                Willy Wonka & the Chocolate Factory
# s8751    Movie                                      Winter's Bone
#
#                                director  \
# show_id
# s55                   Toshiya Shinohara
# s141                 Sebastián Schindel
# ...

# %%
tv_show = df[(df['type'] == 'TV Show') & (df['duration']== '100 min')]

# %%
tv_show
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, release_year, rating, duration, listed_in, description, directoe, Loading year, minutes, units]
# Index: []

# %%
df[(df['type'] == 'Movie') & (df['duration']== '100 min')]
# Out:
#           type                                              title  \
# show_id
# s55      Movie  InuYasha the Movie: Affections Touching Across...
# s141     Movie                El patrón, radiografía de un crimen
# s301     Movie                                               Vivo
# s456     Movie               Emicida: AmarElo - Live in São Paulo
# s462     Movie                                  The Unknown Saint
# ...        ...                                                ...
# s8563    Movie                                The Women's Balcony
# s8623    Movie                             Tremors 2: Aftershocks
# s8628    Movie                                Trespass Against Us
# s8746    Movie                Willy Wonka & the Chocolate Factory
# s8751    Movie                                      Winter's Bone
#
#                                director  \
# show_id
# s55                   Toshiya Shinohara
# s141                 Sebastián Schindel
# ...

# %% [markdown]
# ### all movies directed by Rajiv Chilaka

# %%
df[(df['director']=='Rajiv Chilaka') & (df['type'] == 'Movie') & (df['country'] == 'India')]
# Out:
#           type                                  title       director  \
# show_id
# s411     Movie     Chhota Bheem And The Broken Amulet  Rajiv Chilaka
# s416     Movie               Chhota Bheem aur Krishna  Rajiv Chilaka
# s2718    Movie  Chhota Bheem and the Curse of Damyaan  Rajiv Chilaka
#
#                                                       cast country  \
# show_id
# s411     Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# s416     Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# s2718    Kaustav Ghosh, Jigna Bhardwaj, Chutki, Rajesh ...   India
#
#          release_year rating duration                 listed_in  \
# show_id
# s411             2013  TV-Y7   64 min  Children & Family Movies
# s416             2009  TV-Y7   68 min  Children & Family Movies
# s2718            2012  TV-Y7   87 min  Children & Family Movies
#
#                                                description       directoe  \
# show_id
# ...

# %%
df[(df['type'] == 'Movie') & (df['duration']== '100 min')]
# Out:
#           type                                              title  \
# show_id
# s55      Movie  InuYasha the Movie: Affections Touching Across...
# s141     Movie                El patrón, radiografía de un crimen
# s301     Movie                                               Vivo
# s456     Movie               Emicida: AmarElo - Live in São Paulo
# s462     Movie                                  The Unknown Saint
# ...        ...                                                ...
# s8563    Movie                                The Women's Balcony
# s8623    Movie                             Tremors 2: Aftershocks
# s8628    Movie                                Trespass Against Us
# s8746    Movie                Willy Wonka & the Chocolate Factory
# s8751    Movie                                      Winter's Bone
#
#                                director  \
# show_id
# s55                   Toshiya Shinohara
# s141                 Sebastián Schindel
# ...

# %%
movie
# Out:
#           type                                              title  \
# show_id
# s55      Movie  InuYasha the Movie: Affections Touching Across...
# s141     Movie                El patrón, radiografía de un crimen
# s301     Movie                                               Vivo
# s456     Movie               Emicida: AmarElo - Live in São Paulo
# s462     Movie                                  The Unknown Saint
# ...        ...                                                ...
# s8563    Movie                                The Women's Balcony
# s8623    Movie                             Tremors 2: Aftershocks
# s8628    Movie                                Trespass Against Us
# s8746    Movie                Willy Wonka & the Chocolate Factory
# s8751    Movie                                      Winter's Bone
#
#                                director  \
# show_id
# s55                   Toshiya Shinohara
# s141                 Sebastián Schindel
# ...

# %%
tv_show
# Out:
# Empty DataFrame
# Columns: [type, title, director, cast, country, release_year, rating, duration, listed_in, description, directoe, Loading year, minutes, units]
# Index: []

# %%
total = pd.merge(movie,tv_show,how='outer')
total
# Out:
#       type                                              title  \
# 0    Movie  InuYasha the Movie: Affections Touching Across...
# 1    Movie                El patrón, radiografía de un crimen
# 2    Movie                                               Vivo
# 3    Movie               Emicida: AmarElo - Live in São Paulo
# 4    Movie                                  The Unknown Saint
# ..     ...                                                ...
# 103  Movie                                The Women's Balcony
# 104  Movie                             Tremors 2: Aftershocks
# 105  Movie                                Trespass Against Us
# 106  Movie                Willy Wonka & the Chocolate Factory
# 107  Movie                                      Winter's Bone
#
#                            director  \
# 0                 Toshiya Shinohara
# 1                Sebastián Schindel
# 2    Kirk DeMicco, Brandon Jeffords
# 3                   Fred Ouro Preto
# ...
